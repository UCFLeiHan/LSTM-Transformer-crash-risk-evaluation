# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.10.1

# %% [markdown]
# # 1. Load data and split train and test samples

# %%
data_path = '../data/Risky_driving_behavior.csv' # Risky driving behavior data
oc_path = '../data/Crash_Index.csv' # Crash data
tf_path = '../data/Traffic_flow.csv' #Traffic flow data

data = pd.read_csv(data_path)
oc = pd.read_csv(oc_path)
tf_data = pd.read_csv(tf_path)

# transfer the 'event_id' into unique ID
all_event_id = np.array(data['event_id'].unique())
def inv_list(x):
    d = {}
    for i in range(len(x)):
        d[x[i]] = i
    return d
event_id_to_ind = inv_list(all_event_id)
data['event_id'] = data['event_id'].map(event_id_to_ind)
oc['event_id'] = oc['event_id'].map(event_id_to_ind)

# splot unique ID into train and test (7:3)
all_event_id = oc['event_id'].unique()
np.random.seed(124)
np.random.shuffle(all_event_id)
S = len(all_event_id)
bp = int(0.7*S)
train_event_ind = np.sort(all_event_id[:bp])
test_event_ind = np.sort(all_event_id[bp:])

# %% [markdown]
# # 2. Data process

# %% [markdown]
# ## 2.1 Convert the traffic flow data into time series data for LSTM

# %%
n_timestemps = 5 #length of timestemps 
n_features = 18 #number of features in each time frame
n_obs = n_timestemps * n_features
df1=pd.DataFrame()
df2=pd.DataFrame()

ind_to_event_id = {v: k for k, v in event_id_to_ind.items()} 

decoded_train_event_ids = [ind_to_event_id[ind] for ind in train_event_ind] 
tf_train_data_temp = tf_data.copy()
tf_train_data_temp['event_id'] = pd.Categorical(tf_train_data_temp['event_id'], categories=decoded_train_event_ids, ordered=True) 
tf_train_data = tf_train_data_temp[tf_train_data_temp['event_id'].isin(decoded_train_event_ids)].sort_values('event_id').iloc[:, 1:]

decoded_test_event_ids = [ind_to_event_id[ind] for ind in test_event_ind] 
tf_test_data_temp = tf_data.copy()
tf_test_data_temp['event_id'] = pd.Categorical(tf_test_data_temp['event_id'], categories=decoded_test_event_ids, ordered=True) 
tf_test_data = tf_test_data_temp[tf_test_data_temp['event_id'].isin(decoded_test_event_ids)].sort_values('event_id').iloc[:, 1:]

train_y = tf_train_data['Crash']
train_X= tf_train_data.drop('Crash', axis=1)

for i in range(0,n_timestemps):
    new_column_order = [i + j*n_timestemps for j in range(0, 18)]
    df1 = pd.concat([df1, train_X.iloc[:, new_column_order]], axis=1)

df1 = np.array(df1)
train_X = df1.reshape((train_X.shape[0], n_timestemps, n_features))

test_y = tf_test_data['Crash']
test_X= tf_test_data.drop('Crash', axis=1)
for i in range(0,n_timestemps):
    new_column_order = [i + j*n_timestemps for j in range(0, 18)]
    df2 = pd.concat([df2, test_X.iloc[:, new_column_order]], axis=1)

df2 = np.array(df2)
test_X = df2.reshape((test_X.shape[0], n_timestemps, n_features))

test_y=pd.DataFrame(test_y)
test_y = pd.get_dummies(test_y['Crash'],  prefix='Category')

train_y=pd.DataFrame(train_y)
train_y = pd.get_dummies(train_y['Crash'], prefix='Category')

# %% [markdown]
# ## 2.2 Convert the risky driving behavior data into non-aggregated data for Transformer

# %%
y = np.array(oc.sort_values(by='event_id')['Crash']).astype('float32')
N = data.event_id.max() + 1

data = data.sample(frac=1)
data = data.groupby('event_id').head(880)
N = data.event_id.max() + 1
varis = sorted(list(set(data.variable)))
V = len(varis)
def inv_list(l, start=0):
    d = {}
    for i in range(len(l)):
        d[l[i]] = i+start
    return d
var_to_ind = inv_list(varis, start=1)
data['vind'] = data.variable.map(var_to_ind)
data = data.sort_values(by=['event_id', 'vind', 'time'])

data = data.sort_values(by=['event_id']).reset_index(drop=True)
data = data.reset_index().rename(columns={'index':'obs_ind'})
data = data.merge(data.groupby('event_id').agg({'obs_ind':'min'}).reset_index().rename(columns={'obs_ind':'first_obs_ind'}), on='event_id')
data['obs_ind'] = data['obs_ind'] - data['first_obs_ind']

max_len = data.obs_ind.max()+1 # the maximum number of behaviors included in the samples
print ('max_len', max_len)

# Generate times_ip and values_ip matrices.
times_inp = np.zeros((N, max_len), dtype='float32')
space_inp = np.zeros((N, max_len), dtype='float32')
varis_inp = np.zeros((N, max_len), dtype='int32') 
speed_inp = np.zeros((N, max_len), dtype='float32')
acc_inp = np.zeros((N, max_len), dtype='float32')
duration_inp = np.zeros((N, max_len), dtype='float32')

for row in tqdm(data.itertuples()):
    event_id = row.event_id
    l = row.obs_ind
    times_inp[event_id, l] = row.time
    space_inp[event_id, l] = row.space
    varis_inp[event_id, l] = row.vind
    speed_inp[event_id, l] = row.speed
    acc_inp[event_id, l] = row.acc
    duration_inp[event_id, l] = row.duration
data.drop(columns=['obs_ind', 'first_obs_ind'], inplace=True)
# Generate 3 sets of inputs and outputs.
train_ip = [ip[train_event_ind] for ip in [ times_inp, space_inp, varis_inp, speed_inp, acc_inp, duration_inp]]
test_ip = [ip[test_event_ind] for ip in [ times_inp,space_inp, varis_inp, speed_inp, acc_inp, duration_inp]]
train_op = y[train_event_ind]
test_op = y[test_event_ind]

train_op = train_op[:, np.newaxis]
test_op = test_op[:, np.newaxis]
# Out:
# max_len 206
# 8598it [00:00, 377646.80it/s]

# %% [markdown]
# # 3. Model structure setting

# %% [markdown]
# ## 3.1 Transformer model

# %%
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Layer
from tensorflow.python.ops import array_ops
from tensorflow import nn
from tensorflow.python.framework import smart_cond

# CVE function
class CVE(Layer):
    def __init__(self, hid_units, output_dim):
        self.hid_units = hid_units
        self.output_dim = output_dim
        super(CVE, self).__init__()
        
    def build(self, input_shape): 
        self.W1 = self.add_weight(name='CVE_W1',
                            shape=(1, self.hid_units),
                            initializer='glorot_uniform',
                            trainable=True)
        self.b1 = self.add_weight(name='CVE_b1',
                            shape=(self.hid_units,),
                            initializer='zeros',
                            trainable=True)
        self.W2 = self.add_weight(name='CVE_W2',
                            shape=(self.hid_units, self.output_dim),
                            initializer='glorot_uniform',
                            trainable=True)
        super(CVE, self).build(input_shape)
        
    def call(self, x):
        x = K.expand_dims(x, axis=-1)
        x = K.dot(K.tanh(K.bias_add(K.dot(x, self.W1), self.b1)), self.W2)
        return x
        
    def compute_output_shape(self, input_shape):
        return input_shape + (self.output_dim,)
    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'hid_units': self.hid_units,
            'output_dim': self.output_dim
        })
        return config

# Attention layer
class Attention(Layer):
    
    def __init__(self, hid_dim):
        self.hid_dim = hid_dim
        super(Attention, self).__init__()

    def build(self, input_shape):
        d = input_shape.as_list()[-1]
        self.W = self.add_weight(shape=(d, self.hid_dim), name='Att_W',
                                 initializer='glorot_uniform',
                                 trainable=True)
        self.b = self.add_weight(shape=(self.hid_dim,), name='Att_b',
                                 initializer='zeros',
                                 trainable=True)
        self.u = self.add_weight(shape=(self.hid_dim,1), name='Att_u',
                                 initializer='glorot_uniform',
                                 trainable=True)
        super(Attention, self).build(input_shape)
        
    def call(self, x, mask, mask_value=-1e30):
        attn_weights = K.dot(K.tanh(K.bias_add(K.dot(x,self.W), self.b)), self.u)
        mask = K.expand_dims(mask, axis=-1)
        attn_weights = mask*attn_weights + (1-mask)*mask_value
        attn_weights = K.softmax(attn_weights, axis=-2)
        return attn_weights
        
    def compute_output_shape(self, input_shape):
        return input_shape[:-1] + (1,)
    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'hid_dim': self.hid_dim
        })
        return config

# Overall Transformer model
class Transformer(Layer):
    
    def __init__(self, N=2, h=8, dk=None, dv=None, dff=None, dropout=0):
        self.N, self.h, self.dk, self.dv, self.dff, self.dropout = N, h, dk, dv, dff, dropout
        self.epsilon = K.epsilon() * K.epsilon()
        super(Transformer, self).__init__()

    def build(self, input_shape):
        d = input_shape.as_list()[-1]
        if self.dk==None:
            self.dk = d//self.h
        if self.dv==None:
            self.dv = d//self.h
        if self.dff==None:
            self.dff = 2*d
        self.Wq = self.add_weight(shape=(self.N, self.h, d, self.dk), name='Wq',
                                 initializer='glorot_uniform', trainable=True)
        self.Wk = self.add_weight(shape=(self.N, self.h, d, self.dk), name='Wk',
                                 initializer='glorot_uniform', trainable=True)
        self.Wv = self.add_weight(shape=(self.N, self.h, d, self.dv), name='Wv',
                                 initializer='glorot_uniform', trainable=True)
        self.Wo = self.add_weight(shape=(self.N, self.dv*self.h, d), name='Wo',
                                 initializer='glorot_uniform', trainable=True)
        self.W1 = self.add_weight(shape=(self.N, d, self.dff), name='W1',
                                 initializer='glorot_uniform', trainable=True)
        self.b1 = self.add_weight(shape=(self.N, self.dff), name='b1',
                                 initializer='zeros', trainable=True)
        self.W2 = self.add_weight(shape=(self.N, self.dff, d), name='W2',
                                 initializer='glorot_uniform', trainable=True)
        self.b2 = self.add_weight(shape=(self.N, d), name='b2',
                                 initializer='zeros', trainable=True)
        self.gamma = self.add_weight(shape=(2*self.N,), name='gamma',
                                 initializer='ones', trainable=True)
        self.beta = self.add_weight(shape=(2*self.N,), name='beta',
                                 initializer='zeros', trainable=True)
        super(Transformer, self).build(input_shape)
        
    def call(self, x, mask, mask_value=-1e-30):
        mask = K.expand_dims(mask, axis=-2)
        for i in range(self.N):
            # MHA
            mha_ops = []
            for j in range(self.h):
                q = K.dot(x, self.Wq[i,j,:,:])
                k = K.permute_dimensions(K.dot(x, self.Wk[i,j,:,:]), (0,2,1))
                v = K.dot(x, self.Wv[i,j,:,:])
                A = K.batch_dot(q,k)
                # Mask unobserved steps.
                A = mask*A + (1-mask)*mask_value
                # Mask for attention dropout.
                def dropped_A():
                    dp_mask = K.cast((K.random_uniform(shape=array_ops.shape(A))>=self.dropout), K.floatx())
                    return A*dp_mask + (1-dp_mask)*mask_value
                A = smart_cond.smart_cond(K.learning_phase(), dropped_A, lambda: array_ops.identity(A))
                A = K.softmax(A, axis=-1)
                mha_ops.append(K.batch_dot(A,v))
            conc = K.concatenate(mha_ops, axis=-1)
            proj = K.dot(conc, self.Wo[i,:,:])
            # Dropout.
            proj = smart_cond.smart_cond(K.learning_phase(), lambda: array_ops.identity(nn.dropout(proj, rate=self.dropout)),\
                                       lambda: array_ops.identity(proj))
            # Add & LN
            x = x+proj
            mean = K.mean(x, axis=-1, keepdims=True)
            variance = K.mean(K.square(x - mean), axis=-1, keepdims=True)
            std = K.sqrt(variance + self.epsilon)
            x = (x - mean) / std
            x = x*self.gamma[2*i] + self.beta[2*i]
            # FFN
            ffn_op = K.bias_add(K.dot(K.relu(K.bias_add(K.dot(x, self.W1[i,:,:]), self.b1[i,:])), 
                           self.W2[i,:,:]), self.b2[i,:,])
            # Dropout.
            ffn_op = smart_cond.smart_cond(K.learning_phase(), lambda: array_ops.identity(nn.dropout(ffn_op, rate=self.dropout)),\
                                       lambda: array_ops.identity(ffn_op))
            # Add & LN
            x = x+ffn_op
            mean = K.mean(x, axis=-1, keepdims=True)
            variance = K.mean(K.square(x - mean), axis=-1, keepdims=True)
            std = K.sqrt(variance + self.epsilon)
            x = (x - mean) / std
            x = x*self.gamma[2*i+1] + self.beta[2*i+1]            
        return x
        
    def compute_output_shape(self, input_shape):
        return input_shape
    def get_config(self):
        config = super().get_config().copy()
        config.update({
            'N': self.N,
            'h': self.h,
            'dk': self.dk,
            'dv': self.dv,
            'dff': self.dff,
            'dropout': self.dropout
        })
        return config

# %% [markdown]
# ## 3.2 Transformer+LSTM model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, LSTM, Dense, Add, Lambda,  Embedding
from tensorflow.keras.metrics import Recall, AUC
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import Callback

class EnsembleLayer(tf.keras.layers.Layer):
    def __init__(self, shape, name=None):
        super(EnsembleLayer, self).__init__(name=name)
        self.shape = shape
        
        w = 0.5
        self.alpha1 = self.add_weight(name='alpha1', shape=(),
                                       initializer=tf.keras.initializers.Constant(w),
                                       trainable=True)
        self.alpha2 = self.add_weight(name='alpha2', shape=(),
                                       initializer=tf.keras.initializers.Constant(w),
                                       trainable=True)

    def call(self, inputs):
        output1, output2 = inputs
        # output_new =  output1 * self.alpha1 + output2 * self.alpha2
        output_new = tf.concat([ output1 * self.alpha1 , output2 * self.alpha2], axis=-1)
        return output_new
    
    def get_alpha_values(self):
            return {"alpha1": self.alpha1.numpy(),
                    "alpha2": self.alpha2.numpy()}

class AlphaLogger(Callback):
    def __init__(self, cross_stitch_layer):
        super(AlphaLogger, self).__init__()
        self.cross_stitch_layer = cross_stitch_layer
        self.alpha1_values = []
        self.alpha2_values = []

    def on_epoch_end(self, epoch, logs=None):
        alpha_values = self.cross_stitch_layer.get_alpha_values()
        self.alpha1_values.append(alpha_values["alpha1"])
        self.alpha2_values.append(alpha_values["alpha2"])
        print(f"Epoch {epoch + 1}: alpha1 = {alpha_values['alpha1']}, alpha2 = {alpha_values['alpha2']}")

lstm_input_shape = (n_timestemps, n_features) 
your_epochs = 100
d, N, he, dropout = 50, 2, 4, 0.2
lstm_units = d

# LSTM model
lstm_input = Input(shape=lstm_input_shape)
lstm_new = LSTM(lstm_units, return_sequences=True)(lstm_input)
lstm_out = LSTM(lstm_units, return_sequences=False)(lstm_new)
lstm_final =  Dense(1, activation='sigmoid')(lstm_out)

# Transformer model
times_input = Input(shape=(max_len,))
space_input = Input(shape=(max_len,))
varis_input = Input(shape=(max_len,))
speed_input = Input(shape=(max_len,))
acc_input = Input(shape=(max_len,))
duration_input = Input(shape=(max_len,))

cve_units = int(np.sqrt(d))
times_emb = CVE(cve_units, d)(times_input)
space_emb = CVE(cve_units, d)(space_input)
varis_emb = Embedding(V+1, d)(varis_input)
speed_emb = CVE(cve_units, d)(speed_input)
acc_emb = CVE(cve_units, d)(acc_input)
duration_emb = CVE(cve_units, d)(duration_input)

comb_emb = Add(name='comb_emb')([times_emb, space_emb, varis_emb, speed_emb, acc_emb, duration_emb])
mask = Lambda(lambda x: K.clip(x, 0, 1))(varis_input)  # b, L
cont_emb = Transformer(N, he, dk=None, dv=None, dff=None, dropout=dropout)(comb_emb, mask=mask)
attn_weights = Attention(2*d)(cont_emb, mask=mask)
transformer_out = Lambda(lambda x:K.sum(x[0]*x[1], axis=-2))([cont_emb, attn_weights])
transformer_final =  Dense(1, activation='sigmoid')(transformer_out)

Ensemble_layer = EnsembleLayer(shape=d)
concatenated = Ensemble_layer([lstm_out, transformer_out])
final_out = Dense(1, activation='sigmoid', use_bias=True, bias_initializer='zeros')(concatenated)

# %% [markdown]
# ## 3.3 Model loss & data input setting

# %%
from sklearn.metrics import confusion_matrix, roc_curve
from sklearn.metrics import roc_curve, accuracy_score, recall_score

# Define model loss
class_weights = compute_class_weight(class_weight='balanced', classes=[0, 1], y=train_op.ravel())
class_weights[0] = 1
class_weights[1] = 5
def mortality_loss(y_true, y_pred):
    sample_weights = (1-y_true)*class_weights[0] + y_true*class_weights[1]
    bce = K.binary_crossentropy(y_true, y_pred)
    return K.mean(sample_weights*bce, axis=-1)

# data_ generator function
def data_generator(train_X, train_ip, train_op, batch_size):
    num_samples = len(train_X)
    
    indices = np.arange(num_samples)
    np.random.shuffle(indices)
    
    while True:
        for start_idx in range(0, num_samples, batch_size):
            end_idx = min(start_idx + batch_size, num_samples)
            batch_indices = indices[start_idx:end_idx]
            
            batch_train_X = train_X[batch_indices]
            batch_train_ip = [arr[batch_indices] for arr in train_ip]
            batch_train_op = train_op[batch_indices].reshape(-1, 1)

            input_combined = [batch_train_X] + batch_train_ip

            input_lstm = [batch_train_X]

            input_transformer = batch_train_ip
            
            yield input_combined, batch_train_op, input_lstm, batch_train_op, input_transformer, batch_train_op

        np.random.shuffle(indices)

# Define model evaluation metrics
metrics = ['accuracy', Recall(name='recall'), AUC(name='auc')]
def far(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return 1 - true_negatives / (possible_negatives + K.epsilon())
metrics.append(far)

def evaluate_model_at_specific_far(model, inputs, y_test, far_target=0.2):
    y_pred_prob = model.predict(inputs).ravel()
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
    closest_far_idx = np.argmin(np.abs(fpr - far_target))
    threshold = thresholds[closest_far_idx]
    y_pred = (y_pred_prob >= threshold).astype(int)
    acc = accuracy_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    far = fpr[closest_far_idx]

    return acc, recall, far, threshold

def plot_metrics(history):
    metrics = ['loss', 'accuracy', 'recall', 'auc', 'far']
    for metric in metrics:
        plt.figure()
        plt.plot(history.history[metric], label='Train ' + metric)
        plt.plot(history.history['val_' + metric], label='Validation ' + metric)
        plt.title('Train vs Validation ' + metric)
        plt.legend()
        plt.show()

def plot_confusion_matrix(confusion, title, ax=None):
    if ax is None:
        _, ax = plt.subplots(figsize=(5, 4))
    
    sns.heatmap(confusion, annot=True, fmt="d", cmap="Blues", cbar=False, ax=ax)
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('True Label')
    ax.set_title(title)

def plot_all_confusion_matrices(matrices, titles):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 10))
    
    for ax, matrix, title in zip(axes.ravel(), matrices, titles):
        plot_confusion_matrix(matrix, title, ax=ax)
        
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 4. Model training

# %% [markdown]
# ## 4.1 Transformer+LSTM Model (Both risky driving behavior and traffic flow data)

# %%
from tensorflow.keras.models import Model

# training hyperparameters
batch_size, lr= 64, 5.e-5

model = Model(inputs=[lstm_input, times_input, space_input, varis_input, speed_input, acc_input, duration_input], outputs=final_out)

model.compile(optimizer=Adam(learning_rate=lr), 
              loss=mortality_loss,
              metrics=metrics)

train_gen_combined = ((inputs_combined,y) for inputs_combined, y, _, _, _, _ in data_generator(train_X, train_ip, train_op, batch_size))
val_gen_combined = ((inputs_combined,y) for inputs_combined, y, _, _, _, _ in data_generator(test_X, test_ip, test_op, batch_size))

# Create the alpha logger callback
alpha_logger = AlphaLogger(Ensemble_layer)

# Model training
history_combined = model.fit(
    train_gen_combined,
    steps_per_epoch=len(train_X) // batch_size,
    epochs=your_epochs,
    validation_data=val_gen_combined,
    validation_steps=len(test_X) // batch_size,
    callbacks=[alpha_logger]
)

acc_train, recall_train, far_train, threshold_train = evaluate_model_at_specific_far(model, [train_X] + train_ip, train_op, far_target=0.2)
acc_test, recall_test, far_test, threshold_test = evaluate_model_at_specific_far(model, [test_X] + test_ip, test_op, far_target=0.2)

train_predictions = model.predict([train_X] + train_ip)
train_predictions = (train_predictions > threshold_train).astype(int) 

test_predictions = model.predict([test_X] + test_ip)
test_predictions = (test_predictions > threshold_test).astype(int)

cm_list = [
    confusion_matrix(train_op, train_predictions),
    confusion_matrix(test_op, test_predictions),
]

title_list = [
    "Training Confusion Matrix - Combined",
    "Testing Confusion Matrix - Combined",
]

plot_metrics(history_combined)
plot_all_confusion_matrices(cm_list, title_list)

print("train:")
print(f"cutoff: {threshold_train}")
print(f"accuracy: {acc_train:.4f}, recall: {recall_train:.4f}, FAR: {far_train:.4f}")

print("\ntest:")
print(f"cutoff: {threshold_test}")
print(f"accuracy: {acc_test:.4f}, recall: {recall_test:.4f}, FAR: {far_test:.4f}")
# Out:
# Epoch 1/100
# 14/14 [==============================] - ETA: 0s - loss: 1.2526 - accuracy: 0.7188 - recall: 0.1525 - auc: 0.5013 - far: 0.1485    Epoch 1: alpha1 = 0.49995729327201843, alpha2 = 0.49952423572540283
# 14/14 [==============================] - 11s 150ms/step - loss: 1.2526 - accuracy: 0.7188 - recall: 0.1525 - auc: 0.5013 - far: 0.1485 - val_loss: 1.2726 - val_accuracy: 0.4349 - val_recall: 0.7561 - val_auc: 0.5846 - val_far: 0.6529
# Epoch 2/100
# 14/14 [==============================] - ETA: 0s - loss: 1.2343 - accuracy: 0.2265 - recall: 0.9766 - auc: 0.5515 - far: 0.9520Epoch 2: alpha1 = 0.5002601146697998, alpha2 = 0.49943965673446655
# 14/14 [==============================] - 1s 38ms/step - loss: 1.2343 - accuracy: 0.2265 - recall: 0.9766 - auc: 0.5515 - far: 0.9520 - val_loss: 1.2448 - val_accuracy: 0.2135 - val_recall: 1.0000 - val_auc: 0.6687 - val_far: 1.0000
# Epoch 3/100
# 14/14 [==============================] - ETA: 0s - loss: 1.2078 - accuracy: 0.1925 - recall: 1.0000 - auc: 0.5927 - far: 1.0000Epoch 3: alpha1 = 0.5002516508102417, alpha2 = 0.4995383322238922
# 14/14 [==============================] - 1s 38ms/step - loss: 1.2078 - accuracy: 0.1925 - recall: 1.0000 - auc: 0.5927 - far: 1.0000 - val_loss: 1.2257 - val_accuracy: 0.2083 - val_recall: 1.0000 - val_auc: 0.6805 - val_far: 1.0000
# Epoch 4/100
# 14/14 [==============================] - ETA: 0s - loss: 1.2060 - accuracy: 0.1960 - recall: 0.9940 - auc: 0.6256 - far: 1.0000Epoch 4: alpha1 = 0.5003430843353271, alpha2 = 0.4998427927494049
# 14/14 [==============================] - 1s 38ms/step - loss: 1.2060 - accuracy: 0.1960 - recall: 0.9940 - auc: 0.6256 - far: 1.0000 - val_loss: 1.2169 - val_accuracy: 0.2161 - val_recall: 1.0000 - val_auc: 0.6819 - val_far: 0.9935
# Epoch 5/100
# 14/14 [==============================] - ETA: 0s - loss: 1.2169 - accuracy: 0.2535 - recall: 0.8983 - auc: 0.6462 - far: 0.9184Epoch 5: alpha1 = 0.5006675720214844, alpha2 = 0.5003353953361511
# 14/14 [==============================] - 1s 41ms/step - loss: 1.2169 - accuracy: 0.2535 - recall: 0.8983 - auc: 0.6462 - far: 0.9184 - val_loss: 1.2050 - val_accuracy: 0.3125 - val_recall: 0.9383 - val_auc: 0.6933 - val_far: 0.8550
# Epoch 6/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1962 - accuracy: 0.2475 - recall: 0.9618 - auc: 0.6347 - far: 0.9298Epoch 6: alpha1 = 0.5010719299316406, alpha2 = 0.5010072588920593
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1827 - accuracy: 0.2383 - recall: 0.9634 - auc: 0.6321 - far: 0.9335 - val_loss: 1.1805 - val_accuracy: 0.2292 - val_recall: 0.9873 - val_auc: 0.6902 - val_far: 0.9680
# Epoch 7/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1479 - accuracy: 0.2995 - recall: 0.8571 - auc: 0.6504 - far: 0.8285Epoch 7: alpha1 = 0.5014194250106812, alpha2 = 0.5016182661056519
# 14/14 [==============================] - 1s 38ms/step - loss: 1.1490 - accuracy: 0.3122 - recall: 0.8500 - auc: 0.6525 - far: 0.8127 - val_loss: 1.1782 - val_accuracy: 0.4792 - val_recall: 0.7284 - val_auc: 0.6926 - val_far: 0.5893
# Epoch 8/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.2343 - accuracy: 0.4467 - recall: 0.6667 - auc: 0.6197 - far: 0.6150Epoch 8: alpha1 = 0.5017748475074768, alpha2 = 0.5023475885391235
# 14/14 [==============================] - 1s 40ms/step - loss: 1.2336 - accuracy: 0.4343 - recall: 0.6828 - auc: 0.6136 - far: 0.6329 - val_loss: 1.1718 - val_accuracy: 0.2734 - val_recall: 0.9753 - val_auc: 0.6782 - val_far: 0.9168
# Epoch 9/100
# 14/14 [==============================] - ETA: 0s - loss: 1.1291 - accuracy: 0.2641 - recall: 0.9020 - auc: 0.6525 - far: 0.8792Epoch 9: alpha1 = 0.5021765828132629, alpha2 = 0.5028398633003235
# 14/14 [==============================] - 1s 40ms/step - loss: 1.1291 - accuracy: 0.2641 - recall: 0.9020 - auc: 0.6525 - far: 0.8792 - val_loss: 1.1585 - val_accuracy: 0.4505 - val_recall: 0.7407 - val_auc: 0.6853 - val_far: 0.6292
# Epoch 10/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.2023 - accuracy: 0.5622 - recall: 0.6407 - auc: 0.6323 - far: 0.4683Epoch 10: alpha1 = 0.5026944279670715, alpha2 = 0.5033873319625854
# 14/14 [==============================] - 1s 40ms/step - loss: 1.2121 - accuracy: 0.5575 - recall: 0.6393 - auc: 0.6284 - far: 0.4735 - val_loss: 1.1414 - val_accuracy: 0.5599 - val_recall: 0.6835 - val_auc: 0.6918 - val_far: 0.4732
# Epoch 11/100
# 14/14 [==============================] - ETA: 0s - loss: 1.1138 - accuracy: 0.5986 - recall: 0.6296 - auc: 0.6615 - far: 0.4050Epoch 11: alpha1 = 0.5032070875167847, alpha2 = 0.5040146708488464
# 14/14 [==============================] - 1s 38ms/step - loss: 1.1138 - accuracy: 0.5986 - recall: 0.6296 - auc: 0.6615 - far: 0.4050 - val_loss: 1.1517 - val_accuracy: 0.5781 - val_recall: 0.6341 - val_auc: 0.6853 - val_far: 0.4359
# Epoch 12/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1344 - accuracy: 0.5584 - recall: 0.6267 - auc: 0.6386 - far: 0.4566Epoch 12: alpha1 = 0.5036006569862366, alpha2 = 0.5045305490493774
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1436 - accuracy: 0.5622 - recall: 0.6121 - auc: 0.6333 - far: 0.4488 - val_loss: 1.1421 - val_accuracy: 0.6172 - val_recall: 0.5976 - val_auc: 0.6839 - val_far: 0.3788
# Epoch 13/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1643 - accuracy: 0.6523 - recall: 0.5380 - auc: 0.6253 - far: 0.3065Epoch 13: alpha1 = 0.5040867924690247, alpha2 = 0.5050071477890015
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1474 - accuracy: 0.6573 - recall: 0.5602 - auc: 0.6372 - far: 0.3076 - val_loss: 1.1256 - val_accuracy: 0.6484 - val_recall: 0.5696 - val_auc: 0.6805 - val_far: 0.3302
# Epoch 14/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1383 - accuracy: 0.6079 - recall: 0.6051 - auc: 0.6528 - far: 0.3849Epoch 14: alpha1 = 0.5045897364616394, alpha2 = 0.5054658055305481
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1439 - accuracy: 0.6068 - recall: 0.5965 - auc: 0.6449 - far: 0.3846 - val_loss: 1.1326 - val_accuracy: 0.5885 - val_recall: 0.6585 - val_auc: 0.6887 - val_far: 0.4299
# Epoch 15/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1371 - accuracy: 0.5769 - recall: 0.6196 - auc: 0.6462 - far: 0.4340Epoch 15: alpha1 = 0.5051899552345276, alpha2 = 0.5058189034461975
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1349 - accuracy: 0.5822 - recall: 0.6287 - auc: 0.6525 - far: 0.4209 - val_loss: 1.1217 - val_accuracy: 0.6016 - val_recall: 0.6125 - val_auc: 0.6817 - val_far: 0.4041
# Epoch 16/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1415 - accuracy: 0.6190 - recall: 0.5952 - auc: 0.6551 - far: 0.3732Epoch 16: alpha1 = 0.5057327747344971, alpha2 = 0.5061967968940735
# 14/14 [==============================] - 1s 38ms/step - loss: 1.1430 - accuracy: 0.6172 - recall: 0.5754 - auc: 0.6444 - far: 0.3708 - val_loss: 1.1288 - val_accuracy: 0.6354 - val_recall: 0.5976 - val_auc: 0.6922 - val_far: 0.3531
# Epoch 17/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1241 - accuracy: 0.6751 - recall: 0.5267 - auc: 0.6433 - far: 0.2906Epoch 17: alpha1 = 0.5063163042068481, alpha2 = 0.5064644813537598
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1211 - accuracy: 0.6725 - recall: 0.5337 - auc: 0.6477 - far: 0.2951 - val_loss: 1.1258 - val_accuracy: 0.6797 - val_recall: 0.5309 - val_auc: 0.6876 - val_far: 0.2815
# Epoch 18/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1579 - accuracy: 0.6599 - recall: 0.5404 - auc: 0.6449 - far: 0.3183Epoch 18: alpha1 = 0.506884753704071, alpha2 = 0.5067224502563477
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1654 - accuracy: 0.6585 - recall: 0.5455 - auc: 0.6398 - far: 0.3204 - val_loss: 1.1203 - val_accuracy: 0.6094 - val_recall: 0.6173 - val_auc: 0.6897 - val_far: 0.3940
# Epoch 19/100
# 14/14 [==============================] - ETA: 0s - loss: 1.1199 - accuracy: 0.6009 - recall: 0.6325 - auc: 0.6633 - far: 0.4159Epoch 19: alpha1 = 0.5075625777244568, alpha2 = 0.5069494247436523
# 14/14 [==============================] - 1s 40ms/step - loss: 1.1199 - accuracy: 0.6009 - recall: 0.6325 - auc: 0.6633 - far: 0.4159 - val_loss: 1.1029 - val_accuracy: 0.6484 - val_recall: 0.5949 - val_auc: 0.6999 - val_far: 0.3378
# Epoch 20/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1588 - accuracy: 0.6739 - recall: 0.5595 - auc: 0.6668 - far: 0.2972Epoch 20: alpha1 = 0.5081759095191956, alpha2 = 0.5071870684623718
# 14/14 [==============================] - 1s 40ms/step - loss: 1.1511 - accuracy: 0.6667 - recall: 0.5480 - auc: 0.6540 - far: 0.3032 - val_loss: 1.1062 - val_accuracy: 0.6562 - val_recall: 0.5875 - val_auc: 0.7034 - val_far: 0.3268
# Epoch 21/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1280 - accuracy: 0.6637 - recall: 0.5200 - auc: 0.6384 - far: 0.2960Epoch 21: alpha1 = 0.508746862411499, alpha2 = 0.5073330402374268
# 14/14 [==============================] - 1s 40ms/step - loss: 1.1194 - accuracy: 0.6655 - recall: 0.5217 - auc: 0.6356 - far: 0.2951 - val_loss: 1.1243 - val_accuracy: 0.6797 - val_recall: 0.5422 - val_auc: 0.6972 - val_far: 0.2832
# Epoch 22/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1506 - accuracy: 0.6561 - recall: 0.5190 - auc: 0.6478 - far: 0.3095Epoch 22: alpha1 = 0.5094113349914551, alpha2 = 0.5075349807739258
# 14/14 [==============================] - 1s 40ms/step - loss: 1.1544 - accuracy: 0.6467 - recall: 0.5233 - auc: 0.6446 - far: 0.3217 - val_loss: 1.1079 - val_accuracy: 0.6198 - val_recall: 0.6250 - val_auc: 0.6996 - val_far: 0.3824
# Epoch 23/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0963 - accuracy: 0.6802 - recall: 0.6129 - auc: 0.6935 - far: 0.3008Epoch 23: alpha1 = 0.5101161599159241, alpha2 = 0.5078301429748535
# 14/14 [==============================] - 1s 40ms/step - loss: 1.1006 - accuracy: 0.6737 - recall: 0.5964 - auc: 0.6802 - far: 0.3049 - val_loss: 1.0922 - val_accuracy: 0.6823 - val_recall: 0.5875 - val_auc: 0.7094 - val_far: 0.2962
# Epoch 24/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1589 - accuracy: 0.6802 - recall: 0.5185 - auc: 0.6420 - far: 0.2711Epoch 24: alpha1 = 0.5107763409614563, alpha2 = 0.5080394148826599
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1370 - accuracy: 0.6831 - recall: 0.5266 - auc: 0.6458 - far: 0.2718 - val_loss: 1.1134 - val_accuracy: 0.6745 - val_recall: 0.5488 - val_auc: 0.6963 - val_far: 0.2921
# Epoch 25/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0818 - accuracy: 0.6891 - recall: 0.6069 - auc: 0.6770 - far: 0.3019Epoch 25: alpha1 = 0.5114963054656982, alpha2 = 0.5081371665000916
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0967 - accuracy: 0.6984 - recall: 0.6049 - auc: 0.6808 - far: 0.2879 - val_loss: 1.1006 - val_accuracy: 0.7214 - val_recall: 0.5556 - val_auc: 0.7127 - val_far: 0.2342
# Epoch 26/100
# 14/14 [==============================] - ETA: 0s - loss: 1.1269 - accuracy: 0.6819 - recall: 0.4753 - auc: 0.6346 - far: 0.2640Epoch 26: alpha1 = 0.5122470855712891, alpha2 = 0.5082810521125793
# 14/14 [==============================] - 1s 40ms/step - loss: 1.1269 - accuracy: 0.6819 - recall: 0.4753 - auc: 0.6346 - far: 0.2640 - val_loss: 1.0852 - val_accuracy: 0.7083 - val_recall: 0.5641 - val_auc: 0.7124 - val_far: 0.2549
# Epoch 27/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1522 - accuracy: 0.6561 - recall: 0.4875 - auc: 0.6205 - far: 0.2991Epoch 27: alpha1 = 0.5129212737083435, alpha2 = 0.5083739757537842
# 14/14 [==============================] - 1s 40ms/step - loss: 1.1539 - accuracy: 0.6631 - recall: 0.4798 - auc: 0.6203 - far: 0.2889 - val_loss: 1.1174 - val_accuracy: 0.6927 - val_recall: 0.5542 - val_auc: 0.7012 - val_far: 0.2713
# Epoch 28/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1043 - accuracy: 0.7195 - recall: 0.5605 - auc: 0.7056 - far: 0.2315Epoch 28: alpha1 = 0.5136433243751526, alpha2 = 0.5086197853088379
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0979 - accuracy: 0.7207 - recall: 0.5576 - auc: 0.6979 - far: 0.2316 - val_loss: 1.1040 - val_accuracy: 0.6849 - val_recall: 0.5570 - val_auc: 0.6990 - val_far: 0.2816
# Epoch 29/100
# 14/14 [==============================] - ETA: 0s - loss: 1.1372 - accuracy: 0.6725 - recall: 0.5511 - auc: 0.6682 - far: 0.2840Epoch 29: alpha1 = 0.514397919178009, alpha2 = 0.5088684558868408
# 14/14 [==============================] - 1s 38ms/step - loss: 1.1372 - accuracy: 0.6725 - recall: 0.5511 - auc: 0.6682 - far: 0.2840 - val_loss: 1.1014 - val_accuracy: 0.6693 - val_recall: 0.6098 - val_auc: 0.7119 - val_far: 0.3155
# Epoch 30/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1170 - accuracy: 0.6250 - recall: 0.5938 - auc: 0.6563 - far: 0.3675Epoch 30: alpha1 = 0.5151619911193848, alpha2 = 0.5089884400367737
# 14/14 [==============================] - 1s 40ms/step - loss: 1.1200 - accuracy: 0.6279 - recall: 0.5988 - auc: 0.6609 - far: 0.3577 - val_loss: 1.1009 - val_accuracy: 0.6250 - val_recall: 0.6049 - val_auc: 0.7043 - val_far: 0.3695
# Epoch 31/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1251 - accuracy: 0.6142 - recall: 0.6012 - auc: 0.6548 - far: 0.3819Epoch 31: alpha1 = 0.5159409046173096, alpha2 = 0.5092310905456543
# 14/14 [==============================] - 1s 38ms/step - loss: 1.1258 - accuracy: 0.6172 - recall: 0.6011 - auc: 0.6586 - far: 0.3780 - val_loss: 1.1090 - val_accuracy: 0.6510 - val_recall: 0.5976 - val_auc: 0.7026 - val_far: 0.3384
# Epoch 32/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1266 - accuracy: 0.6916 - recall: 0.5570 - auc: 0.6637 - far: 0.2690Epoch 32: alpha1 = 0.5167458653450012, alpha2 = 0.5094066262245178
# 14/14 [==============================] - 1s 38ms/step - loss: 1.1197 - accuracy: 0.6960 - recall: 0.5509 - auc: 0.6597 - far: 0.2641 - val_loss: 1.0991 - val_accuracy: 0.7057 - val_recall: 0.5679 - val_auc: 0.7050 - val_far: 0.2592
# Epoch 33/100
# 14/14 [==============================] - ETA: 0s - loss: 1.1137 - accuracy: 0.6937 - recall: 0.5689 - auc: 0.6749 - far: 0.2648Epoch 33: alpha1 = 0.5175605416297913, alpha2 = 0.5095512270927429
# 14/14 [==============================] - 1s 41ms/step - loss: 1.1137 - accuracy: 0.6937 - recall: 0.5689 - auc: 0.6749 - far: 0.2648 - val_loss: 1.1100 - val_accuracy: 0.6875 - val_recall: 0.5904 - val_auc: 0.7071 - val_far: 0.2835
# Epoch 34/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1347 - accuracy: 0.6612 - recall: 0.5280 - auc: 0.6598 - far: 0.2945Epoch 34: alpha1 = 0.5185046195983887, alpha2 = 0.5096455812454224
# 14/14 [==============================] - 1s 38ms/step - loss: 1.1292 - accuracy: 0.6596 - recall: 0.5291 - auc: 0.6596 - far: 0.2977 - val_loss: 1.0970 - val_accuracy: 0.6667 - val_recall: 0.6000 - val_auc: 0.7048 - val_far: 0.3150
# Epoch 35/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1040 - accuracy: 0.6992 - recall: 0.5752 - auc: 0.6777 - far: 0.2719Epoch 35: alpha1 = 0.5193143486976624, alpha2 = 0.509823203086853
# 14/14 [==============================] - 1s 37ms/step - loss: 1.1127 - accuracy: 0.6925 - recall: 0.5576 - auc: 0.6642 - far: 0.2758 - val_loss: 1.0889 - val_accuracy: 0.7083 - val_recall: 0.5823 - val_auc: 0.7124 - val_far: 0.2585
# Epoch 36/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0868 - accuracy: 0.7348 - recall: 0.5875 - auc: 0.7163 - far: 0.2346Epoch 36: alpha1 = 0.520164966583252, alpha2 = 0.5100889205932617
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0988 - accuracy: 0.7265 - recall: 0.5690 - auc: 0.7008 - far: 0.2392 - val_loss: 1.0904 - val_accuracy: 0.7109 - val_recall: 0.5570 - val_auc: 0.7094 - val_far: 0.2499
# Epoch 37/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1333 - accuracy: 0.6726 - recall: 0.5000 - auc: 0.6479 - far: 0.2774Epoch 37: alpha1 = 0.5208211541175842, alpha2 = 0.5102055072784424
# 14/14 [==============================] - 1s 38ms/step - loss: 1.1327 - accuracy: 0.6667 - recall: 0.5120 - auc: 0.6501 - far: 0.2876 - val_loss: 1.0830 - val_accuracy: 0.6641 - val_recall: 0.6250 - val_auc: 0.7151 - val_far: 0.3270
# Epoch 38/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0774 - accuracy: 0.6688 - recall: 0.6242 - auc: 0.6926 - far: 0.3143Epoch 38: alpha1 = 0.5217122435569763, alpha2 = 0.510298490524292
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0655 - accuracy: 0.6761 - recall: 0.6250 - auc: 0.7027 - far: 0.3067 - val_loss: 1.1099 - val_accuracy: 0.7240 - val_recall: 0.5062 - val_auc: 0.7063 - val_far: 0.2156
# Epoch 39/100
# 14/14 [==============================] - ETA: 0s - loss: 1.1543 - accuracy: 0.7160 - recall: 0.4830 - auc: 0.6656 - far: 0.2317Epoch 39: alpha1 = 0.5226133465766907, alpha2 = 0.5103780031204224
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1543 - accuracy: 0.7160 - recall: 0.4830 - auc: 0.6656 - far: 0.2317 - val_loss: 1.0944 - val_accuracy: 0.6328 - val_recall: 0.6500 - val_auc: 0.7157 - val_far: 0.3699
# Epoch 40/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0819 - accuracy: 0.5505 - recall: 0.6752 - auc: 0.6820 - far: 0.4826Epoch 40: alpha1 = 0.5234308838844299, alpha2 = 0.5104248523712158
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0819 - accuracy: 0.5505 - recall: 0.6752 - auc: 0.6820 - far: 0.4826 - val_loss: 1.0921 - val_accuracy: 0.5911 - val_recall: 0.7037 - val_auc: 0.7186 - val_far: 0.4392
# Epoch 41/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1250 - accuracy: 0.6485 - recall: 0.6187 - auc: 0.6777 - far: 0.3341Epoch 41: alpha1 = 0.5241853594779968, alpha2 = 0.5105085968971252
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1152 - accuracy: 0.6502 - recall: 0.6294 - auc: 0.6831 - far: 0.3354 - val_loss: 1.0924 - val_accuracy: 0.6693 - val_recall: 0.6250 - val_auc: 0.7219 - val_far: 0.3187
# Epoch 42/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0977 - accuracy: 0.6815 - recall: 0.5860 - auc: 0.6875 - far: 0.2885Epoch 42: alpha1 = 0.5250424742698669, alpha2 = 0.5107014179229736
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0910 - accuracy: 0.6761 - recall: 0.5868 - auc: 0.6893 - far: 0.2957 - val_loss: 1.0984 - val_accuracy: 0.6719 - val_recall: 0.6173 - val_auc: 0.7125 - val_far: 0.3114
# Epoch 43/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1332 - accuracy: 0.6650 - recall: 0.5644 - auc: 0.6765 - far: 0.3107Epoch 43: alpha1 = 0.5259185433387756, alpha2 = 0.510913074016571
# 14/14 [==============================] - 1s 38ms/step - loss: 1.1324 - accuracy: 0.6655 - recall: 0.5650 - auc: 0.6793 - far: 0.3099 - val_loss: 1.0887 - val_accuracy: 0.6719 - val_recall: 0.6000 - val_auc: 0.7139 - val_far: 0.3097
# Epoch 44/100
# 12/14 [========================>.....] - ETA: 0s - loss: 1.1143 - accuracy: 0.6562 - recall: 0.5935 - auc: 0.6812 - far: 0.3280Epoch 44: alpha1 = 0.526765763759613, alpha2 = 0.5109735727310181
# 14/14 [==============================] - 1s 41ms/step - loss: 1.1100 - accuracy: 0.6573 - recall: 0.5941 - auc: 0.6820 - far: 0.3248 - val_loss: 1.0738 - val_accuracy: 0.6901 - val_recall: 0.6375 - val_auc: 0.7377 - val_far: 0.2962
# Epoch 45/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0970 - accuracy: 0.6923 - recall: 0.5767 - auc: 0.6861 - far: 0.2788Epoch 45: alpha1 = 0.5276665687561035, alpha2 = 0.5111580491065979
# 14/14 [==============================] - 1s 40ms/step - loss: 1.0971 - accuracy: 0.6937 - recall: 0.5833 - auc: 0.6904 - far: 0.2780 - val_loss: 1.0739 - val_accuracy: 0.6979 - val_recall: 0.5823 - val_auc: 0.7266 - val_far: 0.2729
# Epoch 46/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1057 - accuracy: 0.7031 - recall: 0.5569 - auc: 0.6925 - far: 0.2601Epoch 46: alpha1 = 0.5286415219306946, alpha2 = 0.511336088180542
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1021 - accuracy: 0.7031 - recall: 0.5562 - auc: 0.6897 - far: 0.2604 - val_loss: 1.0898 - val_accuracy: 0.7083 - val_recall: 0.5976 - val_auc: 0.7329 - val_far: 0.2623
# Epoch 47/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0830 - accuracy: 0.7195 - recall: 0.5455 - auc: 0.7020 - far: 0.2400Epoch 47: alpha1 = 0.5295273661613464, alpha2 = 0.511472225189209
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0830 - accuracy: 0.7195 - recall: 0.5455 - auc: 0.7020 - far: 0.2400 - val_loss: 1.0913 - val_accuracy: 0.7266 - val_recall: 0.5783 - val_auc: 0.7329 - val_far: 0.2334
# Epoch 48/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1090 - accuracy: 0.6764 - recall: 0.5855 - auc: 0.6762 - far: 0.2968Epoch 48: alpha1 = 0.5304567217826843, alpha2 = 0.5115718841552734
# 14/14 [==============================] - 1s 41ms/step - loss: 1.1094 - accuracy: 0.6796 - recall: 0.5976 - auc: 0.6879 - far: 0.2953 - val_loss: 1.0923 - val_accuracy: 0.6589 - val_recall: 0.6829 - val_auc: 0.7257 - val_far: 0.3482
# Epoch 49/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1062 - accuracy: 0.6612 - recall: 0.6182 - auc: 0.7026 - far: 0.3312Epoch 49: alpha1 = 0.531430721282959, alpha2 = 0.5118861198425293
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1021 - accuracy: 0.6502 - recall: 0.6292 - auc: 0.7048 - far: 0.3468 - val_loss: 1.0878 - val_accuracy: 0.6406 - val_recall: 0.6988 - val_auc: 0.7294 - val_far: 0.3727
# Epoch 50/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0720 - accuracy: 0.6739 - recall: 0.5753 - auc: 0.6844 - far: 0.3055Epoch 50: alpha1 = 0.5322462320327759, alpha2 = 0.5120694041252136
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0878 - accuracy: 0.6784 - recall: 0.5688 - auc: 0.6767 - far: 0.2980 - val_loss: 1.0846 - val_accuracy: 0.7161 - val_recall: 0.5875 - val_auc: 0.7243 - val_far: 0.2494
# Epoch 51/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0597 - accuracy: 0.7195 - recall: 0.5532 - auc: 0.6929 - far: 0.2406Epoch 51: alpha1 = 0.5331532955169678, alpha2 = 0.5122195482254028
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0827 - accuracy: 0.7254 - recall: 0.5610 - auc: 0.7038 - far: 0.2304 - val_loss: 1.0790 - val_accuracy: 0.7526 - val_recall: 0.5500 - val_auc: 0.7268 - val_far: 0.1945
# Epoch 52/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1007 - accuracy: 0.6777 - recall: 0.5951 - auc: 0.7100 - far: 0.3019Epoch 52: alpha1 = 0.5341167449951172, alpha2 = 0.5124498605728149
# 14/14 [==============================] - 1s 40ms/step - loss: 1.1266 - accuracy: 0.6573 - recall: 0.5769 - auc: 0.6937 - far: 0.3232 - val_loss: 1.0814 - val_accuracy: 0.6120 - val_recall: 0.7073 - val_auc: 0.7303 - val_far: 0.4115
# Epoch 53/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0826 - accuracy: 0.6548 - recall: 0.6429 - auc: 0.6998 - far: 0.3396Epoch 53: alpha1 = 0.5349603295326233, alpha2 = 0.5125294327735901
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0956 - accuracy: 0.6585 - recall: 0.6412 - auc: 0.6978 - far: 0.3347 - val_loss: 1.0725 - val_accuracy: 0.7214 - val_recall: 0.6125 - val_auc: 0.7344 - val_far: 0.2500
# Epoch 54/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0324 - accuracy: 0.7195 - recall: 0.6096 - auc: 0.7415 - far: 0.2524Epoch 54: alpha1 = 0.5358679890632629, alpha2 = 0.512783408164978
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0341 - accuracy: 0.7218 - recall: 0.6026 - auc: 0.7380 - far: 0.2489 - val_loss: 1.0808 - val_accuracy: 0.7917 - val_recall: 0.5185 - val_auc: 0.7327 - val_far: 0.1346
# Epoch 55/100
# 14/14 [==============================] - ETA: 0s - loss: 1.1001 - accuracy: 0.7606 - recall: 0.4790 - auc: 0.6908 - far: 0.1788Epoch 55: alpha1 = 0.5366924405097961, alpha2 = 0.5129322409629822
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1001 - accuracy: 0.7606 - recall: 0.4790 - auc: 0.6908 - far: 0.1788 - val_loss: 1.0820 - val_accuracy: 0.7188 - val_recall: 0.5976 - val_auc: 0.7339 - val_far: 0.2483
# Epoch 56/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0788 - accuracy: 0.6596 - recall: 0.6412 - auc: 0.7109 - far: 0.3450Epoch 56: alpha1 = 0.5374983549118042, alpha2 = 0.51307213306427
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0788 - accuracy: 0.6596 - recall: 0.6412 - auc: 0.7109 - far: 0.3450 - val_loss: 1.0765 - val_accuracy: 0.6589 - val_recall: 0.6829 - val_auc: 0.7373 - val_far: 0.3466
# Epoch 57/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1049 - accuracy: 0.6675 - recall: 0.5864 - auc: 0.6928 - far: 0.3131Epoch 57: alpha1 = 0.5382856130599976, alpha2 = 0.513258159160614
# 14/14 [==============================] - 1s 39ms/step - loss: 1.1122 - accuracy: 0.6596 - recall: 0.5690 - auc: 0.6827 - far: 0.3183 - val_loss: 1.0728 - val_accuracy: 0.7214 - val_recall: 0.6543 - val_auc: 0.7433 - val_far: 0.2604
# Epoch 58/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0538 - accuracy: 0.7246 - recall: 0.6494 - auc: 0.7387 - far: 0.2703Epoch 58: alpha1 = 0.5391172766685486, alpha2 = 0.5134091973304749
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0669 - accuracy: 0.7136 - recall: 0.6310 - auc: 0.7287 - far: 0.2782 - val_loss: 1.0782 - val_accuracy: 0.6953 - val_recall: 0.6420 - val_auc: 0.7333 - val_far: 0.2944
# Epoch 59/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0662 - accuracy: 0.6675 - recall: 0.6250 - auc: 0.7138 - far: 0.3199Epoch 59: alpha1 = 0.5399924516677856, alpha2 = 0.5135856866836548
# 14/14 [==============================] - 1s 37ms/step - loss: 1.0571 - accuracy: 0.6702 - recall: 0.6149 - auc: 0.7130 - far: 0.3153 - val_loss: 1.0851 - val_accuracy: 0.7552 - val_recall: 0.6098 - val_auc: 0.7382 - val_far: 0.2043
# Epoch 60/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0941 - accuracy: 0.7284 - recall: 0.5893 - auc: 0.7155 - far: 0.2362Epoch 60: alpha1 = 0.5408967137336731, alpha2 = 0.5137419104576111
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0876 - accuracy: 0.7289 - recall: 0.5930 - auc: 0.7166 - far: 0.2372 - val_loss: 1.0698 - val_accuracy: 0.7214 - val_recall: 0.6500 - val_auc: 0.7453 - val_far: 0.2618
# Epoch 61/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0817 - accuracy: 0.6947 - recall: 0.6000 - auc: 0.7148 - far: 0.2815Epoch 61: alpha1 = 0.5418060421943665, alpha2 = 0.5140080451965332
# 14/14 [==============================] - 1s 42ms/step - loss: 1.0755 - accuracy: 0.6953 - recall: 0.6045 - auc: 0.7155 - far: 0.2820 - val_loss: 1.0688 - val_accuracy: 0.7292 - val_recall: 0.6585 - val_auc: 0.7508 - val_far: 0.2515
# Epoch 62/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0588 - accuracy: 0.6942 - recall: 0.6225 - auc: 0.7177 - far: 0.2786Epoch 62: alpha1 = 0.5426951050758362, alpha2 = 0.5143333673477173
# 14/14 [==============================] - 1s 40ms/step - loss: 1.0504 - accuracy: 0.6890 - recall: 0.6203 - auc: 0.7111 - far: 0.2851 - val_loss: 1.0550 - val_accuracy: 0.7109 - val_recall: 0.6500 - val_auc: 0.7478 - val_far: 0.2739
# Epoch 63/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.1036 - accuracy: 0.6954 - recall: 0.6082 - auc: 0.7260 - far: 0.2787Epoch 63: alpha1 = 0.5436552166938782, alpha2 = 0.514580488204956
# 14/14 [==============================] - 1s 41ms/step - loss: 1.0921 - accuracy: 0.7031 - recall: 0.6264 - auc: 0.7348 - far: 0.2750 - val_loss: 1.0742 - val_accuracy: 0.7083 - val_recall: 0.6627 - val_auc: 0.7462 - val_far: 0.2773
# Epoch 64/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0553 - accuracy: 0.7054 - recall: 0.6087 - auc: 0.7198 - far: 0.2726Epoch 64: alpha1 = 0.5444296002388, alpha2 = 0.5148265957832336
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0553 - accuracy: 0.7054 - recall: 0.6087 - auc: 0.7198 - far: 0.2726 - val_loss: 1.0725 - val_accuracy: 0.7734 - val_recall: 0.6375 - val_auc: 0.7420 - val_far: 0.1927
# Epoch 65/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0837 - accuracy: 0.6421 - recall: 0.5975 - auc: 0.7059 - far: 0.3387Epoch 65: alpha1 = 0.5453371405601501, alpha2 = 0.515055239200592
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0902 - accuracy: 0.6268 - recall: 0.5941 - auc: 0.6952 - far: 0.3563 - val_loss: 1.0730 - val_accuracy: 0.5365 - val_recall: 0.7952 - val_auc: 0.7454 - val_far: 0.5333
# Epoch 66/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0476 - accuracy: 0.6573 - recall: 0.6529 - auc: 0.7416 - far: 0.3453Epoch 66: alpha1 = 0.5460973978042603, alpha2 = 0.515248715877533
# 14/14 [==============================] - 1s 40ms/step - loss: 1.0476 - accuracy: 0.6573 - recall: 0.6529 - auc: 0.7416 - far: 0.3453 - val_loss: 1.0642 - val_accuracy: 0.7240 - val_recall: 0.6463 - val_auc: 0.7510 - val_far: 0.2534
# Epoch 67/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0385 - accuracy: 0.6777 - recall: 0.6797 - auc: 0.7463 - far: 0.3319Epoch 67: alpha1 = 0.5469978451728821, alpha2 = 0.5155311226844788
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0571 - accuracy: 0.6772 - recall: 0.6744 - auc: 0.7463 - far: 0.3305 - val_loss: 1.0617 - val_accuracy: 0.7083 - val_recall: 0.6790 - val_auc: 0.7463 - val_far: 0.2854
# Epoch 68/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0850 - accuracy: 0.6536 - recall: 0.5844 - auc: 0.6986 - far: 0.3214Epoch 68: alpha1 = 0.5478305816650391, alpha2 = 0.5156062841415405
# 14/14 [==============================] - 1s 40ms/step - loss: 1.0835 - accuracy: 0.6538 - recall: 0.6048 - auc: 0.7028 - far: 0.3265 - val_loss: 1.0578 - val_accuracy: 0.6771 - val_recall: 0.7284 - val_auc: 0.7568 - val_far: 0.3383
# Epoch 69/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0409 - accuracy: 0.6675 - recall: 0.6159 - auc: 0.7235 - far: 0.3275Epoch 69: alpha1 = 0.5485650300979614, alpha2 = 0.5158441662788391
# 14/14 [==============================] - 1s 42ms/step - loss: 1.0430 - accuracy: 0.6690 - recall: 0.6074 - auc: 0.7211 - far: 0.3233 - val_loss: 1.0735 - val_accuracy: 0.7891 - val_recall: 0.6049 - val_auc: 0.7519 - val_far: 0.1639
# Epoch 70/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0657 - accuracy: 0.7289 - recall: 0.5829 - auc: 0.7432 - far: 0.2291Epoch 70: alpha1 = 0.5494333505630493, alpha2 = 0.5161478519439697
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0657 - accuracy: 0.7289 - recall: 0.5829 - auc: 0.7432 - far: 0.2291 - val_loss: 1.0603 - val_accuracy: 0.5990 - val_recall: 0.7531 - val_auc: 0.7523 - val_far: 0.4426
# Epoch 71/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0316 - accuracy: 0.5990 - recall: 0.7379 - auc: 0.7436 - far: 0.4299Epoch 71: alpha1 = 0.5502517223358154, alpha2 = 0.5163710117340088
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0380 - accuracy: 0.6138 - recall: 0.7233 - auc: 0.7399 - far: 0.4092 - val_loss: 1.0576 - val_accuracy: 0.7578 - val_recall: 0.6420 - val_auc: 0.7571 - val_far: 0.2122
# Epoch 72/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0634 - accuracy: 0.7218 - recall: 0.6307 - auc: 0.7462 - far: 0.2472Epoch 72: alpha1 = 0.5510432720184326, alpha2 = 0.5166097283363342
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0634 - accuracy: 0.7218 - recall: 0.6307 - auc: 0.7462 - far: 0.2472 - val_loss: 1.0569 - val_accuracy: 0.7240 - val_recall: 0.6707 - val_auc: 0.7573 - val_far: 0.2625
# Epoch 73/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0625 - accuracy: 0.6129 - recall: 0.6513 - auc: 0.7123 - far: 0.3982Epoch 73: alpha1 = 0.551866888999939, alpha2 = 0.5168806314468384
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0702 - accuracy: 0.6138 - recall: 0.6407 - auc: 0.7112 - far: 0.3946 - val_loss: 1.0461 - val_accuracy: 0.7266 - val_recall: 0.6500 - val_auc: 0.7575 - val_far: 0.2522
# Epoch 74/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0451 - accuracy: 0.7411 - recall: 0.5769 - auc: 0.7356 - far: 0.2175Epoch 74: alpha1 = 0.5526915788650513, alpha2 = 0.5170925855636597
# 14/14 [==============================] - 1s 40ms/step - loss: 1.0543 - accuracy: 0.7371 - recall: 0.5824 - auc: 0.7355 - far: 0.2234 - val_loss: 1.0364 - val_accuracy: 0.7552 - val_recall: 0.6500 - val_auc: 0.7615 - val_far: 0.2163
# Epoch 75/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0298 - accuracy: 0.6671 - recall: 0.6790 - auc: 0.7444 - far: 0.3343Epoch 75: alpha1 = 0.5534615516662598, alpha2 = 0.5173549652099609
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0377 - accuracy: 0.6631 - recall: 0.6707 - auc: 0.7394 - far: 0.3437 - val_loss: 1.0551 - val_accuracy: 0.7135 - val_recall: 0.7195 - val_auc: 0.7604 - val_far: 0.2867
# Epoch 76/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0539 - accuracy: 0.6731 - recall: 0.6647 - auc: 0.7395 - far: 0.3241Epoch 76: alpha1 = 0.554256021976471, alpha2 = 0.5176305770874023
# 14/14 [==============================] - 1s 40ms/step - loss: 1.0433 - accuracy: 0.6763 - recall: 0.6742 - auc: 0.7427 - far: 0.3226 - val_loss: 1.0495 - val_accuracy: 0.7292 - val_recall: 0.7195 - val_auc: 0.7626 - val_far: 0.2675
# Epoch 77/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0306 - accuracy: 0.7030 - recall: 0.5772 - auc: 0.7302 - far: 0.2755Epoch 77: alpha1 = 0.5550596714019775, alpha2 = 0.5178782343864441
# 14/14 [==============================] - 1s 42ms/step - loss: 1.0401 - accuracy: 0.7066 - recall: 0.5893 - auc: 0.7437 - far: 0.2717 - val_loss: 1.0276 - val_accuracy: 0.7604 - val_recall: 0.6625 - val_auc: 0.7786 - val_far: 0.2126
# Epoch 78/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0221 - accuracy: 0.6739 - recall: 0.6818 - auc: 0.7508 - far: 0.3259Epoch 78: alpha1 = 0.5559059381484985, alpha2 = 0.5181679725646973
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0313 - accuracy: 0.6725 - recall: 0.6765 - auc: 0.7516 - far: 0.3264 - val_loss: 1.0451 - val_accuracy: 0.7422 - val_recall: 0.6585 - val_auc: 0.7643 - val_far: 0.2331
# Epoch 79/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0546 - accuracy: 0.7157 - recall: 0.6065 - auc: 0.7260 - far: 0.2578Epoch 79: alpha1 = 0.5566955208778381, alpha2 = 0.5184077620506287
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0670 - accuracy: 0.7124 - recall: 0.5988 - auc: 0.7270 - far: 0.2591 - val_loss: 1.0363 - val_accuracy: 0.7266 - val_recall: 0.7407 - val_auc: 0.7683 - val_far: 0.2778
# Epoch 80/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0281 - accuracy: 0.7018 - recall: 0.6447 - auc: 0.7506 - far: 0.2920Epoch 80: alpha1 = 0.5574607849121094, alpha2 = 0.5187364220619202
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0341 - accuracy: 0.6984 - recall: 0.6369 - auc: 0.7486 - far: 0.2935 - val_loss: 1.0451 - val_accuracy: 0.7370 - val_recall: 0.7229 - val_auc: 0.7692 - val_far: 0.2573
# Epoch 81/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0317 - accuracy: 0.6624 - recall: 0.6107 - auc: 0.7201 - far: 0.3326Epoch 81: alpha1 = 0.5581042766571045, alpha2 = 0.5189253091812134
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0208 - accuracy: 0.6714 - recall: 0.6226 - auc: 0.7286 - far: 0.3248 - val_loss: 1.0321 - val_accuracy: 0.7812 - val_recall: 0.6296 - val_auc: 0.7710 - val_far: 0.1781
# Epoch 82/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0504 - accuracy: 0.7042 - recall: 0.6047 - auc: 0.7539 - far: 0.2682Epoch 82: alpha1 = 0.5589097142219543, alpha2 = 0.5191335082054138
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0504 - accuracy: 0.7042 - recall: 0.6047 - auc: 0.7539 - far: 0.2682 - val_loss: 1.0459 - val_accuracy: 0.5651 - val_recall: 0.7711 - val_auc: 0.7666 - val_far: 0.4943
# Epoch 83/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0415 - accuracy: 0.6502 - recall: 0.6765 - auc: 0.7424 - far: 0.3594Epoch 83: alpha1 = 0.5595495104789734, alpha2 = 0.5192965865135193
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0415 - accuracy: 0.6502 - recall: 0.6765 - auc: 0.7424 - far: 0.3594 - val_loss: 1.0370 - val_accuracy: 0.8125 - val_recall: 0.6250 - val_auc: 0.7704 - val_far: 0.1372
# Epoch 84/100
# 14/14 [==============================] - ETA: 0s - loss: 0.9838 - accuracy: 0.7430 - recall: 0.5724 - auc: 0.7409 - far: 0.2229Epoch 84: alpha1 = 0.560352623462677, alpha2 = 0.5194967985153198
# 14/14 [==============================] - 1s 41ms/step - loss: 0.9838 - accuracy: 0.7430 - recall: 0.5724 - auc: 0.7409 - far: 0.2229 - val_loss: 1.0429 - val_accuracy: 0.7708 - val_recall: 0.6627 - val_auc: 0.7731 - val_far: 0.2007
# Epoch 85/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0476 - accuracy: 0.6916 - recall: 0.6587 - auc: 0.7613 - far: 0.3009Epoch 85: alpha1 = 0.5611661672592163, alpha2 = 0.5198025107383728
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0484 - accuracy: 0.6843 - recall: 0.6630 - auc: 0.7596 - far: 0.3108 - val_loss: 1.0189 - val_accuracy: 0.6849 - val_recall: 0.7531 - val_auc: 0.7794 - val_far: 0.3338
# Epoch 86/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0137 - accuracy: 0.6942 - recall: 0.6144 - auc: 0.7563 - far: 0.2829Epoch 86: alpha1 = 0.56190025806427, alpha2 = 0.5200601816177368
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0042 - accuracy: 0.6995 - recall: 0.6196 - auc: 0.7592 - far: 0.2786 - val_loss: 1.0384 - val_accuracy: 0.7682 - val_recall: 0.6829 - val_auc: 0.7693 - val_far: 0.2080
# Epoch 87/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0294 - accuracy: 0.7005 - recall: 0.6038 - auc: 0.7539 - far: 0.2756Epoch 87: alpha1 = 0.5627208948135376, alpha2 = 0.5203680992126465
# 14/14 [==============================] - 1s 41ms/step - loss: 1.0413 - accuracy: 0.6972 - recall: 0.6127 - auc: 0.7539 - far: 0.2816 - val_loss: 1.0169 - val_accuracy: 0.6641 - val_recall: 0.7625 - val_auc: 0.7773 - val_far: 0.3621
# Epoch 88/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0276 - accuracy: 0.6772 - recall: 0.6294 - auc: 0.7425 - far: 0.3067Epoch 88: alpha1 = 0.5635157823562622, alpha2 = 0.5206440091133118
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0276 - accuracy: 0.6772 - recall: 0.6294 - auc: 0.7425 - far: 0.3067 - val_loss: 1.0267 - val_accuracy: 0.7266 - val_recall: 0.7073 - val_auc: 0.7744 - val_far: 0.2678
# Epoch 89/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0076 - accuracy: 0.7081 - recall: 0.6178 - auc: 0.7696 - far: 0.2647Epoch 89: alpha1 = 0.564276933670044, alpha2 = 0.5209857225418091
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0090 - accuracy: 0.7077 - recall: 0.6190 - auc: 0.7650 - far: 0.2660 - val_loss: 1.0123 - val_accuracy: 0.7161 - val_recall: 0.7215 - val_auc: 0.7729 - val_far: 0.2843
# Epoch 90/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0153 - accuracy: 0.6995 - recall: 0.6407 - auc: 0.7623 - far: 0.2859Epoch 90: alpha1 = 0.565040111541748, alpha2 = 0.5213529467582703
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0096 - accuracy: 0.6984 - recall: 0.6471 - auc: 0.7646 - far: 0.2949 - val_loss: 1.0157 - val_accuracy: 0.7135 - val_recall: 0.7284 - val_auc: 0.7798 - val_far: 0.2898
# Epoch 91/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0164 - accuracy: 0.7254 - recall: 0.5955 - auc: 0.7604 - far: 0.2416Epoch 91: alpha1 = 0.5657669305801392, alpha2 = 0.5216742753982544
# 14/14 [==============================] - 1s 42ms/step - loss: 1.0164 - accuracy: 0.7254 - recall: 0.5955 - auc: 0.7604 - far: 0.2416 - val_loss: 1.0200 - val_accuracy: 0.7422 - val_recall: 0.7073 - val_auc: 0.7813 - val_far: 0.2482
# Epoch 92/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.9934 - accuracy: 0.7284 - recall: 0.5974 - auc: 0.7686 - far: 0.2365Epoch 92: alpha1 = 0.566477358341217, alpha2 = 0.5220531821250916
# 14/14 [==============================] - 1s 40ms/step - loss: 1.0072 - accuracy: 0.7254 - recall: 0.5774 - auc: 0.7599 - far: 0.2353 - val_loss: 1.0240 - val_accuracy: 0.7318 - val_recall: 0.7037 - val_auc: 0.7720 - val_far: 0.2604
# Epoch 93/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0176 - accuracy: 0.6294 - recall: 0.7595 - auc: 0.7693 - far: 0.3914Epoch 93: alpha1 = 0.5672653913497925, alpha2 = 0.5222662687301636
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0188 - accuracy: 0.6315 - recall: 0.7600 - auc: 0.7718 - far: 0.3908 - val_loss: 1.0314 - val_accuracy: 0.6875 - val_recall: 0.7284 - val_auc: 0.7681 - val_far: 0.3244
# Epoch 94/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.9720 - accuracy: 0.7640 - recall: 0.5594 - auc: 0.7604 - far: 0.1971Epoch 94: alpha1 = 0.567941427230835, alpha2 = 0.5224798321723938
# 14/14 [==============================] - 1s 39ms/step - loss: 0.9819 - accuracy: 0.7641 - recall: 0.5669 - auc: 0.7613 - far: 0.1973 - val_loss: 1.0141 - val_accuracy: 0.7526 - val_recall: 0.6709 - val_auc: 0.7686 - val_far: 0.2254
# Epoch 95/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0415 - accuracy: 0.6455 - recall: 0.6961 - auc: 0.7543 - far: 0.3725Epoch 95: alpha1 = 0.5687116980552673, alpha2 = 0.5225796103477478
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0415 - accuracy: 0.6455 - recall: 0.6961 - auc: 0.7543 - far: 0.3725 - val_loss: 1.0172 - val_accuracy: 0.5911 - val_recall: 0.7901 - val_auc: 0.7811 - val_far: 0.4638
# Epoch 96/100
# 14/14 [==============================] - ETA: 0s - loss: 0.9558 - accuracy: 0.7089 - recall: 0.6497 - auc: 0.7805 - far: 0.2904Epoch 96: alpha1 = 0.5693461894989014, alpha2 = 0.5228726267814636
# 14/14 [==============================] - 1s 38ms/step - loss: 0.9558 - accuracy: 0.7089 - recall: 0.6497 - auc: 0.7805 - far: 0.2904 - val_loss: 1.0334 - val_accuracy: 0.7943 - val_recall: 0.6341 - val_auc: 0.7753 - val_far: 0.1626
# Epoch 97/100
# 14/14 [==============================] - ETA: 0s - loss: 1.0238 - accuracy: 0.6737 - recall: 0.7062 - auc: 0.7653 - far: 0.3311Epoch 97: alpha1 = 0.5701377391815186, alpha2 = 0.5231293439865112
# 14/14 [==============================] - 1s 38ms/step - loss: 1.0238 - accuracy: 0.6737 - recall: 0.7062 - auc: 0.7653 - far: 0.3311 - val_loss: 1.0285 - val_accuracy: 0.5260 - val_recall: 0.7927 - val_auc: 0.7747 - val_far: 0.5453
# Epoch 98/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.9879 - accuracy: 0.7069 - recall: 0.6115 - auc: 0.7766 - far: 0.2678Epoch 98: alpha1 = 0.5708093643188477, alpha2 = 0.5233958959579468
# 14/14 [==============================] - 1s 42ms/step - loss: 0.9880 - accuracy: 0.7077 - recall: 0.6108 - auc: 0.7734 - far: 0.2672 - val_loss: 1.0104 - val_accuracy: 0.7161 - val_recall: 0.7284 - val_auc: 0.7782 - val_far: 0.2872
# Epoch 99/100
# 13/14 [==========================>...] - ETA: 0s - loss: 1.0241 - accuracy: 0.6599 - recall: 0.6667 - auc: 0.7554 - far: 0.3398Epoch 99: alpha1 = 0.5714739561080933, alpha2 = 0.5236018300056458
# 14/14 [==============================] - 1s 40ms/step - loss: 1.0100 - accuracy: 0.6667 - recall: 0.6608 - auc: 0.7591 - far: 0.3311 - val_loss: 1.0203 - val_accuracy: 0.7005 - val_recall: 0.7250 - val_auc: 0.7718 - val_far: 0.3066
# Epoch 100/100
# 13/14 [==========================>...] - ETA: 0s - loss: 0.9575 - accuracy: 0.7386 - recall: 0.6190 - auc: 0.7868 - far: 0.2260Epoch 100: alpha1 = 0.5721562504768372, alpha2 = 0.5238690972328186
# 14/14 [==============================] - 1s 38ms/step - loss: 0.9513 - accuracy: 0.7394 - recall: 0.6289 - auc: 0.7913 - far: 0.2277 - val_loss: 1.0062 - val_accuracy: 0.7240 - val_recall: 0.7375 - val_auc: 0.7829 - val_far: 0.2832
# 29/29 [==============================] - 2s 8ms/step
# 13/13 [==============================] - 0s 8ms/step
# 29/29 [==============================] - 0s 9ms/step
# 13/13 [==============================] - 0s 8ms/step
# train:
# cutoff: 0.5310691595077515
# accuracy: 0.7598, recall: 0.5801, FAR: 0.1959
#
# test:
# cutoff: 0.5256484150886536
# accuracy: 0.7690, recall: 0.6627, FAR: 0.2026

# %% [markdown]
# ## 4.2 Observation of weights of LSTM (traffic flow features) and Transformer (risky driving behavior features)

# %%
import matplotlib.pyplot as plt

# Create a larger figure
plt.figure(figsize=(8, 6)) 

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

plt.plot(alpha_logger.alpha1_values, marker='o', linestyle='-', label='weight for LSTM (traffic flow features)')
plt.plot(alpha_logger.alpha2_values, marker='o', linestyle='-', label='weight for Transformer (risky driving behavior features)')
plt.xlabel('Epoch')
plt.ylabel('Value')
plt.legend()
plt.show()
